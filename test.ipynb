# %%
import io
import hashlib

# %%
passw = "Pass@123"
phash = hashlib.md5(passw.encode('utf-8'))
print(phash.hexdigest()) #hex repres
print(type(phash))
phash = str(phash)
print(type(phash))
phash = hashlib.md5(passw.encode('utf-8'))
print(phash.hexdigest()) #hex repres
phash = str(phash)
# Out:
# f91e15dbec69fc40f81f0876e7009648
# <class '_hashlib.HASH'>
# <class 'str'>
# f91e15dbec69fc40f81f0876e7009648
