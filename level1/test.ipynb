# %%
import json
inputs = ["name","email","age"]
errors = json.dumps(inputs)

# %%
import uuid
id =  "4fbaf82c-fdd0-1-9e43-0456e555007d"
uuid_id = uuid.UUID(id)
print(id)
print(uuid_id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 import uuid
#       2 id =  "4fbaf82c-fdd0-1-9e43-0456e555007d"
# ----> 3 uuid_id = uuid.UUID(id)
#       4 print(id)
#       5 print(uuid_id)
#
# File /usr/lib/python3.12/uuid.py:178, in UUID.__init__(self, hex, bytes, bytes_le, fields, int, version, is_safe)
#     176     hex = hex.strip('{}').replace('-', '')
#     177     if len(hex) != 32:
# --> 178         raise ValueError('badly formed hexadecimal UUID string')
#     179     int = int_(hex, 16)
#     180 if bytes_le is not None:
#
# ValueError: badly formed hexadecimal UUID string

# %%
user = {"id":1,
         "l1" : 2,
         "l3" : 4}
req = {
    "l1" : 3,
    "l3" : 5
}

user = {key : req[key] if key in req else user[key] for key in user}
print(user)
# Out:
# {'id': 1, 'l1': 3, 'l3': 5}
